# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\awezs\\downloads\\titanic_train.csv')
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
survival_count=df['Survived'].value_counts().rename(index={0:'Not Survived',1:'Survived'})
print(survival_count)
# Out:
# Survived
# Not Survived    549
# Survived        342
# Name: count, dtype: int64

# %%
survival_by_gender=df.groupby(['Survived','Sex']).size().rename(index={0:'Not Survived',1:'Survived'})
print(survival_by_gender)
# Out:
# Survived      Sex
# Not Survived  female     81
#               male      468
# Survived      female    233
#               male      109
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Survived', hue='Sex', data=df, palette='cubehelix')
plt.show()

# %%
survival_by_age=df.groupby(['Survived','Age']).size()
print(survival_by_age)
# Out:
# Survived  Age
# 0         1.0     2
#           2.0     7
#           3.0     1
#           4.0     3
#           6.0     1
#                  ..
# 1         58.0    3
#           60.0    2
#           62.0    2
#           63.0    2
#           80.0    1
# Length: 142, dtype: int64

# %%
plt.figure(figsize=(12,7))
sns.lineplot(x='Age',y='Survived',data=df, color='purple')
plt.xticks(range(0, 81, 10))
plt.show()
# Out:
# C:\Users\awezs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\awezs\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
passenger_class_counts = df['Pclass'].value_counts()

plt.figure(figsize=(12, 7))
sns.barplot(x=passenger_class_counts.index, y=passenger_class_counts.values, palette='Set2')
plt.show()

# %%
import pandas as pd
import plotly.express as px
df=pd.read_csv('C:\\Users\\awezs\\downloads\\titanic_train.csv')
fig=px.histogram(x="age" , y="survival_couunt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 4
#       2 import plotly.express as px
#       3 df=pd.read_csv('C:\\Users\\awezs\\downloads\\titanic_train.csv')
# ----> 4 fig=px.histogram(x="age" , y="survival_couunt")
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_chart_types.py:480, in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, text_auto, title, template, width, height)
#     434 def histogram(
#     435     data_frame=None,
#     436     x=None,
#    (...)
# ...
